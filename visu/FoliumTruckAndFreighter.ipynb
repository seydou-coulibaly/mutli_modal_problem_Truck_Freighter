# %%
## INSTANCE 1
## Loading data in python

import pandas as pd

mydata = pd.read_csv('../instances2018/C1-2-8.txt',sep='\t')
mydata
## Plotting all points on the map


import folium

m = folium.Map(location=[47.22, -1.555],
    zoom_start=11)

for i in range(0,len(mydata)):
    #myicon=folium.Icon(icon='box',prefix='fa',color='blue')
    myicon= folium.Icon(color='lightgreen',icon='cube',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="D":
        myicon=folium.Icon(color='red',icon='truck',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="P":
        myicon=folium.Icon(color='darkblue',icon='sign-out', prefix='fa') 
            #myicon=folium.Icon(icon='fa-cafe',prefix='map-icon')
    if mydata.iloc[i]['VERTEX_TYPE']=="L":
        myicon= folium.Icon(color='darkgreen',icon='cubes',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="LS":
        myicon= folium.Icon(color='green',icon='cubes',prefix='fa')
    popuptxt = str(mydata.iloc[i]['CUSTNO']) + '\t' + \
        str(mydata.iloc[i]['DEMAND']) +  '\t' + \
        mydata.iloc[i]['VERTEX_TYPE'] +  '\t' + \
        str(mydata.iloc[i]['LATITUDE']) +  '\t' + \
        str(mydata.iloc[i]['LONGITUDE']) +  '\t' + \
        str(mydata.iloc[i]['TW_OPENING'])
    folium.Marker(location=[mydata.iloc[i]['LATITUDE'], mydata.iloc[i]['LONGITUDE']], icon=myicon,  popup=popuptxt).add_to(m)
m
## Drawing some lines between points (small truck)

scdata =  pd.read_csv('../log/S-C1-2-8.txt',sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="red", weight=2.5, opacity=0.8).add_to(m)
scdata =  pd.read_csv('../log/B-C1-2-8.txt',sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="blue", weight=2.5, opacity=0.8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## INSTANCE 2
## Loading data in python

import pandas as pd
fname = 'C1-3-10.txt'

mydata = pd.read_csv('../instances2018/'+fname,sep='\t')

mydata

## Plotting all points on the map

import folium

m = folium.Map(location=[47.22, -1.555],
    zoom_start=11)

for i in range(0,len(mydata)):
    #myicon=folium.Icon(icon='box',prefix='fa',color='blue')
    myicon= folium.Icon(color='lightgreen',icon='cube',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="D":
        myicon=folium.Icon(color='red',icon='truck',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="P":
        myicon=folium.Icon(color='darkblue',icon='sign-out', prefix='fa') 
            #myicon=folium.Icon(icon='fa-cafe',prefix='map-icon')
    if mydata.iloc[i]['VERTEX_TYPE']=="L":
        myicon= folium.Icon(color='darkgreen',icon='cubes',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="LS":
        myicon= folium.Icon(color='green',icon='cubes',prefix='fa')
    popuptxt = str(mydata.iloc[i]['CUSTNO']) + '\t' + \
        str(mydata.iloc[i]['DEMAND']) +  '\t' + \
        mydata.iloc[i]['VERTEX_TYPE'] +  '\t' + \
        str(mydata.iloc[i]['LATITUDE']) +  '\t' + \
        str(mydata.iloc[i]['LONGITUDE']) +  '\t' + \
        str(mydata.iloc[i]['TW_OPENING'])
    folium.Marker(location=[mydata.iloc[i]['LATITUDE'], mydata.iloc[i]['LONGITUDE']], icon=myicon,  popup=popuptxt).add_to(m)
m
## Drawing some lines between points (small truck)
scdata =  pd.read_csv('../log/S-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="red", weight=2.5, opacity=0.8).add_to(m)

## Drawing some lines between points (big truck)
scdata =  pd.read_csv('../log/B-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
scpoints
folium.PolyLine(scpoints,color="blue", weight=2.5, opacity=0.8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## INSTANCE 3
## Loading data in python

import pandas as pd
fname = 'C1-3-12.txt'

mydata = pd.read_csv('../instances2018/'+fname,sep='\t')

mydata

## Plotting all points on the map

import folium

m = folium.Map(location=[47.22, -1.555],
    zoom_start=11)

for i in range(0,len(mydata)):
    #myicon=folium.Icon(icon='box',prefix='fa',color='blue')
    myicon= folium.Icon(color='lightgreen',icon='cube',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="D":
        myicon=folium.Icon(color='red',icon='truck',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="P":
        myicon=folium.Icon(color='darkblue',icon='sign-out', prefix='fa') 
            #myicon=folium.Icon(icon='fa-cafe',prefix='map-icon')
    if mydata.iloc[i]['VERTEX_TYPE']=="L":
        myicon= folium.Icon(color='darkgreen',icon='cubes',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="LS":
        myicon= folium.Icon(color='green',icon='cubes',prefix='fa')
    popuptxt = str(mydata.iloc[i]['CUSTNO']) + '\t' + \
        str(mydata.iloc[i]['DEMAND']) +  '\t' + \
        mydata.iloc[i]['VERTEX_TYPE'] +  '\t' + \
        str(mydata.iloc[i]['LATITUDE']) +  '\t' + \
        str(mydata.iloc[i]['LONGITUDE']) +  '\t' + \
        str(mydata.iloc[i]['TW_OPENING'])
    folium.Marker(location=[mydata.iloc[i]['LATITUDE'], mydata.iloc[i]['LONGITUDE']], icon=myicon,  popup=popuptxt).add_to(m)
m
## Drawing some lines between points (small truck)
scdata =  pd.read_csv('../log/S-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="red", weight=2.5, opacity=0.8).add_to(m)

## Drawing some lines between points (big truck)
scdata =  pd.read_csv('../log/B-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
scpoints
folium.PolyLine(scpoints,color="blue", weight=2.5, opacity=0.8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## INSTANCE 4
## Loading data in python

import pandas as pd
fname = 'C2-2-8.txt'

mydata = pd.read_csv('../instances2018/'+fname,sep='\t')

mydata

## Plotting all points on the map

import folium

m = folium.Map(location=[47.22, -1.555],
    zoom_start=11)

for i in range(0,len(mydata)):
    #myicon=folium.Icon(icon='box',prefix='fa',color='blue')
    myicon= folium.Icon(color='lightgreen',icon='cube',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="D":
        myicon=folium.Icon(color='red',icon='truck',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="P":
        myicon=folium.Icon(color='darkblue',icon='sign-out', prefix='fa') 
            #myicon=folium.Icon(icon='fa-cafe',prefix='map-icon')
    if mydata.iloc[i]['VERTEX_TYPE']=="L":
        myicon= folium.Icon(color='darkgreen',icon='cubes',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="LS":
        myicon= folium.Icon(color='green',icon='cubes',prefix='fa')
    popuptxt = str(mydata.iloc[i]['CUSTNO']) + '\t' + \
        str(mydata.iloc[i]['DEMAND']) +  '\t' + \
        mydata.iloc[i]['VERTEX_TYPE'] +  '\t' + \
        str(mydata.iloc[i]['LATITUDE']) +  '\t' + \
        str(mydata.iloc[i]['LONGITUDE']) +  '\t' + \
        str(mydata.iloc[i]['TW_OPENING'])
    folium.Marker(location=[mydata.iloc[i]['LATITUDE'], mydata.iloc[i]['LONGITUDE']], icon=myicon,  popup=popuptxt).add_to(m)
m
## Drawing some lines between points (small truck)
scdata =  pd.read_csv('../log/S-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="red", weight=2.5, opacity=0.8).add_to(m)

## Drawing some lines between points (big truck)
scdata =  pd.read_csv('../log/B-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
scpoints
folium.PolyLine(scpoints,color="blue", weight=2.5, opacity=0.8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## INSTANCE 5
## Loading data in python

import pandas as pd
fname = 'C2-3-10.txt'

mydata = pd.read_csv('../instances2018/'+fname,sep='\t')

mydata

## Plotting all points on the map

import folium

m = folium.Map(location=[47.22, -1.555],
    zoom_start=11)

for i in range(0,len(mydata)):
    #myicon=folium.Icon(icon='box',prefix='fa',color='blue')
    myicon= folium.Icon(color='lightgreen',icon='cube',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="D":
        myicon=folium.Icon(color='red',icon='truck',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="P":
        myicon=folium.Icon(color='darkblue',icon='sign-out', prefix='fa') 
            #myicon=folium.Icon(icon='fa-cafe',prefix='map-icon')
    if mydata.iloc[i]['VERTEX_TYPE']=="L":
        myicon= folium.Icon(color='darkgreen',icon='cubes',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="LS":
        myicon= folium.Icon(color='green',icon='cubes',prefix='fa')
    popuptxt = str(mydata.iloc[i]['CUSTNO']) + '\t' + \
        str(mydata.iloc[i]['DEMAND']) +  '\t' + \
        mydata.iloc[i]['VERTEX_TYPE'] +  '\t' + \
        str(mydata.iloc[i]['LATITUDE']) +  '\t' + \
        str(mydata.iloc[i]['LONGITUDE']) +  '\t' + \
        str(mydata.iloc[i]['TW_OPENING'])
    folium.Marker(location=[mydata.iloc[i]['LATITUDE'], mydata.iloc[i]['LONGITUDE']], icon=myicon,  popup=popuptxt).add_to(m)
m
## Drawing some lines between points (small truck)
scdata =  pd.read_csv('../log/S-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="red", weight=2.5, opacity=0.8).add_to(m)

## Drawing some lines between points (big truck)
scdata =  pd.read_csv('../log/B-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
scpoints
folium.PolyLine(scpoints,color="blue", weight=2.5, opacity=0.8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## INSTANCE 6
## Loading data in python

import pandas as pd
fname = 'C2-3-12.txt'

mydata = pd.read_csv('../instances2018/'+fname,sep='\t')

mydata

## Plotting all points on the map

import folium

m = folium.Map(location=[47.22, -1.555],
    zoom_start=11)

for i in range(0,len(mydata)):
    #myicon=folium.Icon(icon='box',prefix='fa',color='blue')
    myicon= folium.Icon(color='lightgreen',icon='cube',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="D":
        myicon=folium.Icon(color='red',icon='truck',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="P":
        myicon=folium.Icon(color='darkblue',icon='sign-out', prefix='fa') 
            #myicon=folium.Icon(icon='fa-cafe',prefix='map-icon')
    if mydata.iloc[i]['VERTEX_TYPE']=="L":
        myicon= folium.Icon(color='darkgreen',icon='cubes',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="LS":
        myicon= folium.Icon(color='green',icon='cubes',prefix='fa')
    popuptxt = str(mydata.iloc[i]['CUSTNO']) + '\t' + \
        str(mydata.iloc[i]['DEMAND']) +  '\t' + \
        mydata.iloc[i]['VERTEX_TYPE'] +  '\t' + \
        str(mydata.iloc[i]['LATITUDE']) +  '\t' + \
        str(mydata.iloc[i]['LONGITUDE']) +  '\t' + \
        str(mydata.iloc[i]['TW_OPENING'])
    folium.Marker(location=[mydata.iloc[i]['LATITUDE'], mydata.iloc[i]['LONGITUDE']], icon=myicon,  popup=popuptxt).add_to(m)
m
## Drawing some lines between points (small truck)
scdata =  pd.read_csv('../log/S-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="red", weight=2.5, opacity=0.8).add_to(m)

## Drawing some lines between points (big truck)
scdata =  pd.read_csv('../log/B-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
scpoints
folium.PolyLine(scpoints,color="blue", weight=2.5, opacity=0.8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## IINSTANCE 7
#INFEASIBLE

# %%
## INSTANCE 8
## Loading data in python

import pandas as pd
fname = 'R1-3-10.txt'

mydata = pd.read_csv('../instances2018/'+fname,sep='\t')

mydata

## Plotting all points on the map

import folium

m = folium.Map(location=[47.22, -1.555],
    zoom_start=11)

for i in range(0,len(mydata)):
    #myicon=folium.Icon(icon='box',prefix='fa',color='blue')
    myicon= folium.Icon(color='lightgreen',icon='cube',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="D":
        myicon=folium.Icon(color='red',icon='truck',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="P":
        myicon=folium.Icon(color='darkblue',icon='sign-out', prefix='fa') 
            #myicon=folium.Icon(icon='fa-cafe',prefix='map-icon')
    if mydata.iloc[i]['VERTEX_TYPE']=="L":
        myicon= folium.Icon(color='darkgreen',icon='cubes',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="LS":
        myicon= folium.Icon(color='green',icon='cubes',prefix='fa')
    popuptxt = str(mydata.iloc[i]['CUSTNO']) + '\t' + \
        str(mydata.iloc[i]['DEMAND']) +  '\t' + \
        mydata.iloc[i]['VERTEX_TYPE'] +  '\t' + \
        str(mydata.iloc[i]['LATITUDE']) +  '\t' + \
        str(mydata.iloc[i]['LONGITUDE']) +  '\t' + \
        str(mydata.iloc[i]['TW_OPENING'])
    folium.Marker(location=[mydata.iloc[i]['LATITUDE'], mydata.iloc[i]['LONGITUDE']], icon=myicon,  popup=popuptxt).add_to(m)
m
## Drawing some lines between points (small truck)
scdata =  pd.read_csv('../log/S-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="red", weight=2.5, opacity=0.8).add_to(m)

## Drawing some lines between points (big truck)
scdata =  pd.read_csv('../log/B-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
scpoints
folium.PolyLine(scpoints,color="blue", weight=2.5, opacity=0.8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## INSTANCE 9
## Loading data in python

import pandas as pd
fname = 'R1-3-12.txt'

mydata = pd.read_csv('../instances2018/'+fname,sep='\t')

mydata

## Plotting all points on the map

import folium

m = folium.Map(location=[47.22, -1.555],
    zoom_start=11)

for i in range(0,len(mydata)):
    #myicon=folium.Icon(icon='box',prefix='fa',color='blue')
    myicon= folium.Icon(color='lightgreen',icon='cube',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="D":
        myicon=folium.Icon(color='red',icon='truck',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="P":
        myicon=folium.Icon(color='darkblue',icon='sign-out', prefix='fa') 
            #myicon=folium.Icon(icon='fa-cafe',prefix='map-icon')
    if mydata.iloc[i]['VERTEX_TYPE']=="L":
        myicon= folium.Icon(color='darkgreen',icon='cubes',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="LS":
        myicon= folium.Icon(color='green',icon='cubes',prefix='fa')
    popuptxt = str(mydata.iloc[i]['CUSTNO']) + '\t' + \
        str(mydata.iloc[i]['DEMAND']) +  '\t' + \
        mydata.iloc[i]['VERTEX_TYPE'] +  '\t' + \
        str(mydata.iloc[i]['LATITUDE']) +  '\t' + \
        str(mydata.iloc[i]['LONGITUDE']) +  '\t' + \
        str(mydata.iloc[i]['TW_OPENING'])
    folium.Marker(location=[mydata.iloc[i]['LATITUDE'], mydata.iloc[i]['LONGITUDE']], icon=myicon,  popup=popuptxt).add_to(m)
m
## Drawing some lines between points (small truck)
scdata =  pd.read_csv('../log/S-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="red", weight=2.5, opacity=0.8).add_to(m)

## Drawing some lines between points (big truck)
scdata =  pd.read_csv('../log/B-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
scpoints
folium.PolyLine(scpoints,color="blue", weight=2.5, opacity=0.8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## INSTANCE 10
## Loading data in python

import pandas as pd
fname = 'R2-2-8.txt'

mydata = pd.read_csv('../instances2018/'+fname,sep='\t')

mydata

## Plotting all points on the map

import folium

m = folium.Map(location=[47.22, -1.555],
    zoom_start=11)

for i in range(0,len(mydata)):
    #myicon=folium.Icon(icon='box',prefix='fa',color='blue')
    myicon= folium.Icon(color='lightgreen',icon='cube',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="D":
        myicon=folium.Icon(color='red',icon='truck',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="P":
        myicon=folium.Icon(color='darkblue',icon='sign-out', prefix='fa') 
            #myicon=folium.Icon(icon='fa-cafe',prefix='map-icon')
    if mydata.iloc[i]['VERTEX_TYPE']=="L":
        myicon= folium.Icon(color='darkgreen',icon='cubes',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="LS":
        myicon= folium.Icon(color='green',icon='cubes',prefix='fa')
    popuptxt = str(mydata.iloc[i]['CUSTNO']) + '\t' + \
        str(mydata.iloc[i]['DEMAND']) +  '\t' + \
        mydata.iloc[i]['VERTEX_TYPE'] +  '\t' + \
        str(mydata.iloc[i]['LATITUDE']) +  '\t' + \
        str(mydata.iloc[i]['LONGITUDE']) +  '\t' + \
        str(mydata.iloc[i]['TW_OPENING'])
    folium.Marker(location=[mydata.iloc[i]['LATITUDE'], mydata.iloc[i]['LONGITUDE']], icon=myicon,  popup=popuptxt).add_to(m)
m
## Drawing some lines between points (small truck)
scdata =  pd.read_csv('../log/S-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="red", weight=2.5, opacity=0.8).add_to(m)

## Drawing some lines between points (big truck)
scdata =  pd.read_csv('../log/B-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
scpoints
folium.PolyLine(scpoints,color="blue", weight=2.5, opacity=0.8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## INSTANCE 11
## Loading data in python

import pandas as pd
fname = 'R2-3-10.txt'

mydata = pd.read_csv('../instances2018/'+fname,sep='\t')

mydata

## Plotting all points on the map

import folium

m = folium.Map(location=[47.22, -1.555],
    zoom_start=11)

for i in range(0,len(mydata)):
    #myicon=folium.Icon(icon='box',prefix='fa',color='blue')
    myicon= folium.Icon(color='lightgreen',icon='cube',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="D":
        myicon=folium.Icon(color='red',icon='truck',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="P":
        myicon=folium.Icon(color='darkblue',icon='sign-out', prefix='fa') 
            #myicon=folium.Icon(icon='fa-cafe',prefix='map-icon')
    if mydata.iloc[i]['VERTEX_TYPE']=="L":
        myicon= folium.Icon(color='darkgreen',icon='cubes',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="LS":
        myicon= folium.Icon(color='green',icon='cubes',prefix='fa')
    popuptxt = str(mydata.iloc[i]['CUSTNO']) + '\t' + \
        str(mydata.iloc[i]['DEMAND']) +  '\t' + \
        mydata.iloc[i]['VERTEX_TYPE'] +  '\t' + \
        str(mydata.iloc[i]['LATITUDE']) +  '\t' + \
        str(mydata.iloc[i]['LONGITUDE']) +  '\t' + \
        str(mydata.iloc[i]['TW_OPENING'])
    folium.Marker(location=[mydata.iloc[i]['LATITUDE'], mydata.iloc[i]['LONGITUDE']], icon=myicon,  popup=popuptxt).add_to(m)
m
## Drawing some lines between points (small truck)
scdata =  pd.read_csv('../log/S-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="red", weight=2.5, opacity=0.8).add_to(m)

## Drawing some lines between points (big truck)
scdata =  pd.read_csv('../log/B-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
scpoints
folium.PolyLine(scpoints,color="blue", weight=2.5, opacity=0.8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## INSTANCE 12
## Loading data in python

import pandas as pd
fname = 'R2-3-12.txt'

mydata = pd.read_csv('../instances2018/'+fname,sep='\t')

mydata

## Plotting all points on the map

import folium

m = folium.Map(location=[47.22, -1.555],
    zoom_start=11)

for i in range(0,len(mydata)):
    #myicon=folium.Icon(icon='box',prefix='fa',color='blue')
    myicon= folium.Icon(color='lightgreen',icon='cube',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="D":
        myicon=folium.Icon(color='red',icon='truck',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="P":
        myicon=folium.Icon(color='darkblue',icon='sign-out', prefix='fa') 
            #myicon=folium.Icon(icon='fa-cafe',prefix='map-icon')
    if mydata.iloc[i]['VERTEX_TYPE']=="L":
        myicon= folium.Icon(color='darkgreen',icon='cubes',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="LS":
        myicon= folium.Icon(color='green',icon='cubes',prefix='fa')
    popuptxt = str(mydata.iloc[i]['CUSTNO']) + '\t' + \
        str(mydata.iloc[i]['DEMAND']) +  '\t' + \
        mydata.iloc[i]['VERTEX_TYPE'] +  '\t' + \
        str(mydata.iloc[i]['LATITUDE']) +  '\t' + \
        str(mydata.iloc[i]['LONGITUDE']) +  '\t' + \
        str(mydata.iloc[i]['TW_OPENING'])
    folium.Marker(location=[mydata.iloc[i]['LATITUDE'], mydata.iloc[i]['LONGITUDE']], icon=myicon,  popup=popuptxt).add_to(m)
m
## Drawing some lines between points (small truck)
scdata =  pd.read_csv('../log/S-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="red", weight=2.5, opacity=0.8).add_to(m)

## Drawing some lines between points (big truck)
scdata =  pd.read_csv('../log/B-'+fname,sep='\t')
scdata
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
scpoints
folium.PolyLine(scpoints,color="blue", weight=2.5, opacity=0.8).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## INSTANCE NANTES

## Loading data in python

import pandas as pd

mydata = pd.read_csv('../instances2018/instanceNantes.txt',sep='\t')

mydata
# Out:
#     CUSTNO  DEMAND VERTEX_TYPE   LATITUDE  LONGITUDE  TW_OPENING
# 0        1       0           D  47.282609  -1.520303           0
# 1       15       0           P  47.234018  -1.535018           0
# 2       17       0           P  47.214782  -1.528867           0
# 3       20       0           P  47.235291  -1.546796           0
# 4       30       0           P  47.229754  -1.572034           0
# 5       34       0           P  47.205724  -1.548747           0
# 6       36       0           P  47.221261  -1.585622           0
# 7       41       0           P  47.233521  -1.565815           0
# 8       64       0           P  47.208880  -1.568500           0
# 9       73       0           P  47.225871  -1.523495           0
# 10      81       0           P  47.228290  -1.578915           0
# 11      84       0           P  47.212329  -1.579016           0
# 12      85       0           P  47.214044  -1.585142           0
# 13       3      40           S  47.214248  -1.557261       10800
# 14       6      20           S  47.221100  -1.555272       18000
# 15       9      40           S  47.216294  -1.551915        7200
# 16      12      50           S  47.219669  -1.555670           0
# 17      13      50           S  47.217890  -1.542601       10800
# 18      14      30           S  47.229771  -1.554525        3600
# 19      18      10           S  47.216174  -1.561164       19800
# 20      19      10           S  47.213795  -1.556156        7200
# 21      21      20           S  47.219554  -1.534063        5400
# 22      22      40           S  47.224999  -1.529539       23400
# 23      24      30           S  47.221644  -1.559282        3600
# 24      25      40           S  47.217716  -1.551740        1800
# 25      31      10           S  47.215738  -1.558752       14400
# 26      35      50           S  47.216722  -1.555231        7200
# 27      45      30           S  47.222295  -1.530817       12600
# 28      47      40           S  47.214090  -1.553507       10800
# 29      48      30           S  47.214954  -1.574183       25200
# ..     ...     ...         ...        ...        ...         ...
# 56      33      50          LS  47.214668  -1.567069       10800
# 57      37      60          LS  47.214010  -1.585108       14400
# 58      38      50          LS  47.208220  -1.529422       16200
# 59      39      30          LS  47.216273  -1.599214       23400
# 60      40      50          LS  47.202134  -1.544655        9000
# 61      42     100          LS  47.236236  -1.563558       16200
# 62      44      20          LS  47.230202  -1.523560        1800
# 63      46      90          LS  47.221651  -1.559239        1800
# 64      49      60          LS  47.227355  -1.542256       21600
# 65      50      80          LS  47.252381  -1.567387       18000
# 66      53      90          LS  47.234715  -1.541116        1800
# 67      56      80          LS  47.244620  -1.533591       25200
# 68      59      20          LS  47.214017  -1.585140        3600
# 69      60      50          LS  47.248587  -1.530053        1800
# 70      66      80          LS  47.220703  -1.548304       16200
# 71      70      10          LS  47.242906  -1.524187       18000
# 72      77     100          LS  47.239172  -1.570886       16200
# 73      78     100          LS  47.223438  -1.598438        1800
# 74      79      90          LS  47.232873  -1.576907       25200
# 75      82      40          LS  47.228217  -1.578851       12600
# 76      83      30          LS  47.209999  -1.595902        5400
# 77      86      40          LS  47.207237  -1.558786       18000
# 78      87      90          LS  47.240526  -1.591229       23400
# 79      91      90          LS  47.236071  -1.584305       14400
# 80      92      80          LS  47.228719  -1.604925       14400
# 81      93      60          LS  47.232531  -1.591553       21600
# 82      95     100          LS  47.207209  -1.505761        3600
# 83      96      90          LS  47.209355  -1.611343       21600
# 84      97      60          LS  47.235269  -1.582865       23400
# 85      98      10          LS  47.222160  -1.606121       23400
#
# [86 rows x 6 columns]

# %%
## Plotting all points on the map


import folium

m = folium.Map(location=[47.22, -1.555],
    zoom_start=11)

for i in range(0,len(mydata)):
    #myicon=folium.Icon(icon='box',prefix='fa',color='blue')
    myicon= folium.Icon(color='lightgreen',icon='cube',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="D":
        myicon=folium.Icon(color='red',icon='truck',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="P":
        myicon=folium.Icon(color='darkblue',icon='sign-out', prefix='fa') 
            #myicon=folium.Icon(icon='fa-cafe',prefix='map-icon')
    if mydata.iloc[i]['VERTEX_TYPE']=="L":
        myicon= folium.Icon(color='darkgreen',icon='cubes',prefix='fa')
    if mydata.iloc[i]['VERTEX_TYPE']=="LS":
        myicon= folium.Icon(color='green',icon='cubes',prefix='fa')
    popuptxt = str(mydata.iloc[i]['CUSTNO']) + '\t' + \
        str(mydata.iloc[i]['DEMAND']) +  '\t' + \
        mydata.iloc[i]['VERTEX_TYPE'] +  '\t' + \
        str(mydata.iloc[i]['LATITUDE']) +  '\t' + \
        str(mydata.iloc[i]['LONGITUDE']) +  '\t' + \
        str(mydata.iloc[i]['TW_OPENING'])
    folium.Marker(location=[mydata.iloc[i]['LATITUDE'], mydata.iloc[i]['LONGITUDE']], icon=myicon,  popup=popuptxt).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## Drawing some lines between points at random 

scdata = mydata[mydata.VERTEX_TYPE=="S"]
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="red", weight=2.5, opacity=0.8).add_to(m)

scdata = mydata[mydata.VERTEX_TYPE=="LS"]
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="blue", weight=2.5, opacity=0.8).add_to(m)

scdata = mydata[mydata.VERTEX_TYPE=="P"]
scpoints = list(zip(scdata.LATITUDE, scdata.LONGITUDE))
folium.PolyLine(scpoints,color="green", weight=2.5, opacity=0.8).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
